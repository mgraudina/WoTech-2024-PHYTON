# %% [markdown]
# <a href="https://colab.research.google.com/github/mgraudina/WoTech-2024-PHYTON/blob/main/07_13_Data_Analysis_Panda_%2B_Pyplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **L14: Exploratory data analysis with Pandas library || and introduction to Pyplot**
#
# 1. Introduction to matplotlib.plotly library
# 2. Difference between df.plot() and plt.plot()
# 3. Visualising different data visualisation types (line, bar, h-bar, pie, histogram, scatter plot, boxplot)
# 4. Deep dive into Pandas value_counts

# %%
# MATPLOTLIB -->

# plotting library in Python
# used for data vizualization
# https://matplotlib.org/stable/gallery/index.html


# sample data: representing the average temperature (in degrees Celsius) from 2010 to 2014
# data = object = dictionary

data = {'Year': [2010, 2011, 2012, 2013, 2014],
        'Avg_Temperature': [14.1, 14.3, 14.5, 14.2, 14.6]}
import pandas as pd
import matplotlib.pyplot as plt # sub-library "pyplot"; abbreviation "plt"
df = pd.DataFrame(data)
df

# VERSION ONE (= simple line chart)

plt.plot(df['Year'], df['Avg_Temperature'], marker="o")

plt.title("Average temperature from 2010 to 2014") # add title
plt.xlabel("Year") # title of x-axis
plt.ylabel("Temperature") # title of y-axis

plt.xticks(df["Year"]) # year values are rounded
plt.grid(True) # add grid
plt.show() # show vizualisation (won´t print logs of the vizualisation before plot, if used)

# ticks --> values of x -and y-axis
# square brackets [] --> refer to column
# 1st value = X-axis; 2nd value = Y-axes

# %%
## Grid
plt.grid(True)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.minorticks_on()

# %%
# VERSION TWO

# difference in code (vs version one) --> 1st line of code
# main difference (vs version one) --> customization of plot; to create/control customizations --> use 1st

# df.plot --> for quick, simple data vizualisations

df.plot(x='Year', y='Avg_Temperature', kind='line') # plotting wrapper, cannot have df with same column names, need to define what kind of chart we use
plt.title('Average temperature from 2010 to 2014') # add title
plt.xlabel('Year') # title of x-axis
plt.ylabel('Temperature') # title of y-axis

plt.xticks(df['Year'])
plt.grid(True)
plt.show() #show visualization

# %% [markdown]
# ``` there should be notebook after lecture to read about the difference, CHECK!!!!

# %%
# BAR CHART

plt.bar(df['Year'], df['Avg_Temperature'], color='skyblue') #color can be selected
plt.title('Avg temperature from 2010 to 2014')
plt.xlabel('Year')
plt.ylabel('Temperature')
# Out:
# Text(0, 0.5, 'Temperature')

# %%
# H-BAR CHART (horizontal)

plt.barh(df['Year'], df['Avg_Temperature'], color='orange') # BAR vs BARH
plt.title('Avg temperature from 2010 to 2014')
plt.xlabel('Temperature')
plt.ylabel('Year')
# Out:
# Text(0, 0.5, 'Year')

# %%
# HISTOGRAM - presents the distribution of a single variable; frequency

data2 = {'Scores': [85, 92, 78, 20, 89, 90, 82, 56, 60, 23, 90, 40, 77]} # dictionary, key is "scores"
df2 = pd.DataFrame(data2) # input data2 to DataFrame
df2

plt.hist(df2["Scores"], bins=3, color="green", edgecolor="black")

# plt = print, column "Scores"
# bins = in how many groups data will be grouped, will divide data in equal sizes

# array([20., 44., 68., 92.]) = bins 20-43; 44-67; 68-92
# Out:
# (array([3., 2., 8.]),
#  array([20., 44., 68., 92.]),
#  <BarContainer object of 3 artists>)

# %%
# CUSTOM BIN EDGES

bin_edges = [0, 40, 60, 80, 90, 100]
plt.hist(df2["Scores"], bins=bin_edges, color ="red", edgecolor= "black")
# Out:
# (array([2., 2., 3., 3., 3.]),
#  array([  0.,  40.,  60.,  80.,  90., 100.]),
#  <BarContainer object of 5 artists>)

# %%
# SCATTER PLOT - used to visualize the relationship btw two variables

data3 = {"X": [1,2,3,5,5,2], "Y": [5,8,7,4,9,5]} # has to be equal nr of data, otherwise error

df3 = pd.DataFrame(data3)
df3

plt.scatter(x = df3["X"], y =df3["Y"])
plt.title("Scatter Plot")
plt.grid(True)

# Markers:
# https://matplotlib.org/stable/gallery/lines_bars_and_markers/scatter_star_poly.html

# %%
# Sample (by Laila)

import numpy as np
# Linear trendline
z = np.polyfit(df3['X'], df3['Y'], 1)
p = np.poly1d(z)
# Plot the trendline
plt.plot(df3['X'], p(df3['X']), color='red')

# %%
# To change grid color

plt.grid(True, which='both', linestyle='--', linewidth=0.1, color='red')

# %%
# PIE CHART - represents parts of a whole

data4 = {'Category': ['A', 'B', 'C', 'D'], 'Values': [15, 30, 25, 40]}
df4 = pd.DataFrame(data4)
df4
# Out:
#   Category  Values
# 0        A      15
# 1        B      30
# 2        C      25
# 3        D      40

# %%
colors = ['pink', 'cyan', 'skyblue', 'yellow'] #counterclokwise

plt.pie(df4["Values"], labels = df4["Category"], autopct="%1.1f%%", colors=colors) #floating point at decimetal 1,1
plt.title("Pie Chart")
plt.show()

# %%
# BOX PLOT - distribution of dataset and identifies outliers

plt.boxplot(df4["Values"])
plt.grid(True)
plt.show()

# in the middle - middle value, then outlayers
# 25% quartiles; 50% within the box

# %% [markdown]
# ### VALUE COUNTS

# %%
dataset = pd.read_csv('/content/transaction_dataset.csv') # reading the file

# %%
dataset.head() # looking at first values, default 5
# Out:
#    Customer ID      Name    Surname Gender   Birthdate  Transaction Amount  \
# 0       752858      Sean  Rodriguez      F  20/10/2002               35.47
# 1        26381  Michelle     Phelps    NaN  24/10/1985             2552.72
# 2       305449     Jacob   Williams      M  25/10/1981              115.97
# 3       988259    Nathan     Snyder      M  26/10/1977               11.31
# 4       764762   Crystal      Knapp      F  02/11/1951               62.21
#
#          Date               Merchant Name     Category
# 0  03/04/2023               Smith-Russell     Cosmetic
# 1  17/07/2023      Peck, Spence and Young       Travel
# 2  20/09/2023                  Steele Inc     Clothing
# 3  11/01/2023  Wilson, Wilson and Russell     Cosmetic
# 4  13/06/2023               Palmer-Hinton  Electronics

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         50000 non-null  int64
#  1   Name                50000 non-null  object
#  2   Surname             50000 non-null  object
#  3   Gender              44953 non-null  object
#  4   Birthdate           50000 non-null  object
#  5   Transaction Amount  50000 non-null  float64
#  6   Date                50000 non-null  object
#  7   Merchant Name       50000 non-null  object
#  8   Category            50000 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 3.4+ MB

# %%
# VALUE COUNTS

# frequency of each value in your data set
# works on series --> have to define a column

dataset["Category"].value_counts()
# Out:
# Category
# Restaurant     8413
# Market         8382
# Travel         8377
# Electronics    8324
# Clothing       8261
# Cosmetic       8243
# Name: count, dtype: int64

# %%
dataset["Gender"].value_counts()
# Out:
# Gender
# F    22713
# M    22240
# Name: count, dtype: int64

# %%
dataset['Gender'].value_counts(dropna=False).reset_index() #to see also NaN values
# Out:
#   Gender  count
# 0      F  22713
# 1      M  22240
# 2    NaN   5047

# %%
# .reset_index method: restes the index - to create dataframe with new index
# (other option is to import pandas)

# %% [markdown]
# TEAMWORK

# %%
# TASK 1:
# Create a bar chart that shows the count of customers for each unique value in the 'Gender' column (including NaN values). - easy

# %%
import matplotlib.pyplot as plt
import pandas as pd

dataset = pd.read_csv('/content/transaction_dataset.csv')
dataf = pd.DataFrame(dataset)

dataset['Gender'] = dataset['Gender'].astype(str)
dataset['Gender'].value_counts()
gender_counts = dataset['Gender'].value_counts(dropna=False).reset_index()
gender_counts.columns = ['Gender', 'Counts']
df = pd.DataFrame(gender_counts)

plt.bar(df['Gender'], df['Counts'], color=['thistle','skyblue', 'orange'], edgecolor='maroon')

plt.title('Customers per Gender')
plt.xlabel('Gender')
plt.ylabel('Amount')
# Out:
# Text(0, 0.5, 'Amount')

# %%
# TASK 2:
# Create a horizontal bar chart that shows the top 5 most frequent names in the DataFrame, based on the 'name' column. (First, create a grouped DataFrame (name_df), then filter it using iloc, and finally create the visualization.) - medium

# %%
name_df = pd.DataFrame(dataset['Name'].value_counts().reset_index())
name_df.columns = ['Name', 'Counts']

filtered_names = name_df.iloc[:5]

plt.barh(filtered_names['Name'], filtered_names['Counts'], color='skyblue')
plt.title('Top 5 names')
plt.ylabel('Names')
plt.xlabel('Frequency')

plt.show()

# %%
# TASK 3
# Create a filtered DataFrame that includes Category == 'Clothing' and Gender == 'M'. How many rows are there in this filtered DataFrame? Format the result as follows: The filtered DataFrame has XXXX rows. - hard

# %%
filtered_df = dataf[dataf['Gender'] == 'M'][dataf['Category'] == 'Clothing']
rows = len(filtered_df)
print(f'The filtered DataFrame has {rows} rows.')
# Out:
# The filtered DataFrame has 3738 rows.
# <ipython-input-5-3ac527d33d3d>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_df = dataf[dataf['Gender'] == 'M'][dataf['Category'] == 'Clothing']
